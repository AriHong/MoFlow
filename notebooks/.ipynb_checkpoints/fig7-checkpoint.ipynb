# %%
import glob
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from scipy import sparse
import anndata
import seaborn as sns
import scvelo as scv
import scanpy as sc

# %%
import matplotlib
matplotlib.rcParams.update({'font.size': 12})
matplotlib.rcParams.update({'figure.facecolor': 'white'})
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
matplotlib.rcParams['svg.fonttype'] = 'none'

matplotlib.rcParams['ytick.labelright'] = False
matplotlib.rcParams['ytick.labelleft'] = True
matplotlib.rcParams['ytick.right'] = False
matplotlib.rcParams['ytick.left'] = True

# %%
import sys
sys.path.append("../src/")
import MoFlow as mf

# %%
scvelo = anndata.read_h5ad(
    '../data/Mouse_brain/adata_scvelo.h5ad')
multivelo = anndata.read_h5ad(
    '../data/Mouse_brain/adata_multivelo.h5ad')
celldancer = anndata.read_h5ad(
    '../data/Mouse_brain/adata_celldancer.h5ad')

# %%
adata_out = anndata.read_h5ad(
    '../data/Mouse_brain/adata_moflow.h5ad')

# %%
multivelo.layers['Mc'] = multivelo.layers['ATAC']
multivelo.layers['c'] = multivelo.layers['Mc']
multivelo.layers['u'] = multivelo.layers['Mu']
multivelo.layers['s'] = multivelo.layers['Ms']
multivelo.layers['velo_c'] = multivelo.layers['velo_chrom']

# %%
labels = pd.read_csv('../temps/250325_mousebrain_cluster.csv', index_col=0)

# %%
model_df = mf.eval.get_genescore(adata_out)
genes = list(set(model_df.index) & set(labels.index))
labels = labels.loc[genes]
model_df = model_df.loc[genes]
adata_out = adata_out[:, genes]

# %%
from scipy.ndimage import uniform_filter1d

# %%
fig, axes = plt.subplots(12, 1, figsize=(2.4, 1.2*12))
for i in range(12):
    target = adata_out[:, labels[labels['label']==i].index].layers['Mc']
    target_ = target.mean(axis=1)
    target_ = target_[np.argsort(adata_out.obs['velo_s_pseudotime'].ravel())]
    target_ = uniform_filter1d(target_, 100)
    target_ = target_ - target_.min()
    target_ = target_/target_.max()
    axes[i].plot(range(target_.shape[0]), target_, color='#102E50', label='c')
    
    target = adata_out[:, labels[labels['label']==i].index].layers['Ms']
    target_ = target.mean(axis=1)
    target_ = target_[np.argsort(adata_out.obs['velo_s_pseudotime'].ravel())]
    target_ = uniform_filter1d(target_, 100)
    target_ = target_ - target_.min()
    target_ = target_/target_.max()
    axes[i].plot(range(target_.shape[0]), target_, color='#BE3D2A', label='s')
    
    axes[i].set_xticks([])
    axes[i].set_yticks([])
    axes[i].set_ylabel(f'Cluster {i}')
axes[0].legend()

fig.savefig('../figures/fig7A.pdf')

# %%
from fastdtw import fastdtw

# %%
def normalize(x):
    return (x - np.min(x)) / (np.max(x) - np.min(x))
def smooth(x, size=3):# smoothing
    return uniform_filter1d(x, size=size)
def pad_ends(x):# Add zero to both ends
    return np.concatenate([[0], x, [0]])

def bin_and_average(x, time, n_bins=20):
    bins = np.linspace(np.min(time), np.max(time), n_bins + 1)
    binned = np.digitize(time, bins) - 1
    out = np.array([np.mean(x[binned == i]) for i in range(n_bins)])
    return out


def get_dtw(adata, gene, genetime=False, timekey = 'velo_s_pseudotime_', n_bins=20):
    #if genetime:
    #    adata_ = adata[np.argsort(adata[:, gene].layers[timekey].ravel())]
    #else:
    #    adata_ = adata[np.argsort(adata.obs[timekey])]
    #c = adata_[:, gene].layers['Mc'].ravel()
    #u = adata_[:, gene].layers['Mu'].ravel()
    #s = adata_[:, gene].layers['Ms'].ravel()
    
    if genetime:
        time = adata[:, gene].layers[timekey].ravel()
    else:
        time = adata.obs[timekey].values
    time = np.clip(time, 0, np.quantile(time, 0.95))

    c = adata[:, gene].layers['Mc'].ravel()
    u = adata[:, gene].layers['Mu'].ravel()
    s = adata[:, gene].layers['Ms'].ravel()
    
    c = bin_and_average(c, time, n_bins)
    u = bin_and_average(u, time, n_bins)
    s = bin_and_average(s, time, n_bins)


    c_norm = normalize(c)
    u_norm = normalize(u)
    s_norm = normalize(s)

    c_smooth = smooth(c_norm)
    u_smooth = smooth(u_norm)
    s_smooth = smooth(s_norm)

    c_pad = pad_ends(c_smooth)
    u_pad = pad_ends(u_smooth)
    s_pad = pad_ends(s_smooth)
    
    #print(c_pad.shape, s_pad.shape)
    #print(np.any(np.isnan(c_pad)), np.any(np.isinf(c_pad), np.any(np.isnan(s_pad)), np.any(np.isinf(s_pad))))
    #print(c_pad)
    time_pad = np.linspace(0, 1, len(c_pad))


    distance_c_s, path_c_s = fastdtw(c_pad, s_pad, )
    distance_u_s, path_u_s = fastdtw(u_pad, s_pad, )

    time_lag_c_s = [time_pad[j] - time_pad[i] for i, j in path_c_s]
    time_lag_u_s = [time_pad[j] - time_pad[i] for i, j in path_u_s]
    return(time_pad, c_pad, u_pad, s_pad, path_c_s, path_u_s, time_lag_c_s, time_lag_u_s)

def plot(gene, time_pad, c_pad, u_pad, s_pad, path_c_s, path_u_s, time_lag_c_s, time_lag_u_s, 
         axvspan='clusterbig', legend=['Astro', 'Oligo', 'Exc'],
         figsave=None):

    fig, axs = plt.subplots(2, 1, figsize=(4.8, 3.2), sharex=True)

    # Top: c vs s
    axs[0].plot(time_pad, c_pad, label='c', color='#102E50')
    axs[0].plot(time_pad, u_pad, label='u', color='#F5C45E')
    axs[0].plot(time_pad, s_pad, label='s', color='#BE3D2A')
    
    for i, j in path_c_s[::3]:  # skip some lines for clarity
        axs[0].plot([time_pad[i], time_pad[j]], [c_pad[i], s_pad[j]], 'k--', linewidth=0.5)
    for i, j in path_u_s[::3]:
        axs[0].plot([time_pad[i], time_pad[j]], [u_pad[i], s_pad[j]], 'k--', linewidth=0.5)
    
    axs[0].set_ylabel("Norm values")
    axs[0].legend()
    axs[0].set_title("DTW Alignment")

    # Middle: u vs s
    #axs[1].plot(time_pad, u_pad, label='u', color='#F5C45E')
    #axs[1].plot(time_pad, s_pad, label='s', color='#BE3D2A')
    #for i, j in path_u_s[::3]:
    #    axs[1].plot([time_pad[i], time_pad[j]], [u_pad[i], s_pad[j]], 'k--', linewidth=0.5)
    #axs[1].set_ylabel("Norm values")
    #axs[1].legend()
    #axs[1].set_title("DTW Alignment: u vs s")

    # Bottom: time lag
    axs[1].plot([time_pad[i] for i, _ in path_c_s], time_lag_c_s, label='c-s lag', color='#3E3F5B')
    axs[1].plot([time_pad[i] for i, _ in path_u_s], time_lag_u_s, label='u-s lag', color='#8AB2A6')
    axs[1].axhline(0, color='gray', linestyle='--')
    axs[1].set_ylabel("Time lag")
    axs[1].set_xlabel("Time")
    axs[1].legend()
    #axs[2].set_title("Instantaneous Time Lags")
    
    fig.suptitle(gene)

    plt.tight_layout()
    plt.show()
    
    if figsave is not None:
        fig.savefig(figsave)

# %%
from scipy.interpolate import interp1d

def resample_timelag(timelag, n=22):
    x_old = np.linspace(0, 1, len(timelag))
    x_new = np.linspace(0, 1, n)
    f = interp1d(x_old, timelag, kind='linear', fill_value='extrapolate')
    return f(x_new)

# %%
nangene = []
time_lag_c_s_ = []
time_lag_u_s_ = []

c_pad_ = []
u_pad_ = []
s_pad_ = []

for g in adata_out.var_names:
    try:
        
        time_pad, c_pad, u_pad, s_pad, time_lag_c_s, path_u_s, time_lag_c_s, time_lag_u_s= mf.eval_dtw.get_dtw(
            adata_out, g, timekey='velo_s_pseudotime')
        time_lag_c_s_.append(resample_timelag(time_lag_c_s))
        time_lag_u_s_.append(resample_timelag(time_lag_u_s))
        c_pad_.append(c_pad)
        u_pad_.append(u_pad)
        s_pad_.append(s_pad)
        
    except:
        nangene.append(g)
time_lag_c_s_mf = pd.DataFrame(time_lag_c_s_, index=indices_mf)
time_lag_u_s_mf = pd.DataFrame(time_lag_u_s_, index=indices_mf)

# %%
indices_mf = np.setdiff1d(adata_out.var_names, np.array(nangene))

# %%
time_lag_c_s_mf = pd.DataFrame(time_lag_c_s_, index=indices_mf)
time_lag_u_s_mf = pd.DataFrame(time_lag_u_s_, index=indices_mf)

# %%
c_pad_mf = pd.DataFrame(c_pad_, index=indices_mf)
u_pad_mf = pd.DataFrame(u_pad_, index=indices_mf)
s_pad_mf = pd.DataFrame(s_pad_, index=indices_mf)
zero_pd_mf = (c_pad_mf>0.01)|(u_pad_mf>0.01)|(s_pad_mf>0.01)

# %%
time_lag_c_s_mf_ = time_lag_c_s_mf*zero_pd_mf
time_lag_u_s_mf_ = time_lag_u_s_mf*zero_pd_mf

# %%
nangene = []
time_lag_c_s_ = []
time_lag_u_s_ = []

c_pad_ = []
u_pad_ = []
s_pad_ = []
for g in adata_out.var_names:
    try:
        
        time_pad, c_pad, u_pad, s_pad, time_lag_c_s, path_u_s, time_lag_c_s, time_lag_u_s= mf.eval_dtw.get_dtw(
            multivelo, g, timekey='latent_time')
        time_lag_c_s_.append(resample_timelag(time_lag_c_s))
        time_lag_u_s_.append(resample_timelag(time_lag_u_s))
        c_pad_.append(c_pad)
        u_pad_.append(u_pad)
        s_pad_.append(s_pad)
        
    except:
        nangene.append(g)

# %%
indices_mv = np.setdiff1d(adata_out.var_names, np.array(nangene))

# %%
time_lag_c_s_mv = pd.DataFrame(time_lag_c_s_, index=indices_mv)
time_lag_u_s_mv = pd.DataFrame(time_lag_u_s_, index=indices_mv)

# %%
c_pad_mv = pd.DataFrame(c_pad_, index=indices_mv)
u_pad_mv = pd.DataFrame(u_pad_, index=indices_mv)
s_pad_mv = pd.DataFrame(s_pad_, index=indices_mv)
zero_pd_mv = (c_pad_mv>0.01)|(u_pad_mv>0.01)|(s_pad_mv>0.01)

# %%
time_lag_c_s_mv_ = time_lag_c_s_mv*zero_pd_mv
time_lag_u_s_mv_ = time_lag_u_s_mv*zero_pd_mv

# %%
fig, ax = plt.subplots(figsize=(3.2, 2.4))
for i, qt in enumerate([0, .25, .5, .75, 1.]):
    plt.stackplot(range(22), np.quantile(time_lag_c_s_mf_, qt, axis=0), 
                  color=sns.color_palette('hls', 6)[i], alpha=.3)
for i, qt in enumerate([0, .25, .5, .75, 1.]):
    plt.plot(range(22), np.quantile(time_lag_c_s_mf_, qt, axis=0), 
             color=sns.color_palette('hls',6)[i], label=f'q{int(qt*100)}')
plt.axhline(0, ls='--', color='grey')
plt.legend()
ax.set_xlabel('Pseudotime')
ax.set_ylabel('dt')
ax.set_title('Gene expression and chromatin accessibility dt')
fig.savefig('../figures/fig7B.pdf')

# %%
fig, ax = plt.subplots(figsize=(3.2, 2.4))
for i, qt in enumerate([0, .25, .5, .75, 1.]):
    plt.stackplot(range(22), np.quantile(time_lag_c_s_mv_, qt, axis=0), 
                  color=sns.color_palette('hls', 6)[i], alpha=.3)
for i, qt in enumerate([0, .25, .5, .75, 1.]):
    plt.plot(range(22), np.quantile(time_lag_c_s_mv_, qt, axis=0), 
             color=sns.color_palette('hls',6)[i], label=f'q{int(qt*100)}')
    
plt.legend()
plt.axhline(0, ls='--', color='grey')

ax.set_xlabel('Latent time')
ax.set_ylabel('dt')
ax.set_title('Gene expression and chromatin accessibility dt')
fig.savefig('../figures/fig7B_S.pdf')

# %%
from sklearn.metrics import pairwise
from sklearn.cluster import AgglomerativeClustering
n_cluster=6

# %%
cluster = AgglomerativeClustering(n_clusters=n_cluster, linkage='average')
cluster_labels = cluster.fit_predict(time_lag_c_s_mf_)

# %%
sns.color_palette("Set2", n_cluster)
# Out:
# [(0.4, 0.7607843137254902, 0.6470588235294118),
#  (0.9882352941176471, 0.5529411764705883, 0.3843137254901961),
#  (0.5529411764705883, 0.6274509803921569, 0.796078431372549),
#  (0.9058823529411765, 0.5411764705882353, 0.7647058823529411),
#  (0.6509803921568628, 0.8470588235294118, 0.32941176470588235),
#  (1.0, 0.8509803921568627, 0.1843137254901961)]

# %%
sns.clustermap(time_lag_c_s_mf_, cmap='coolwarm', col_cluster=False,
               row_colors=pd.DataFrame(cluster_labels, index=time_lag_c_s_mf_.index)[0].map(
    dict(zip(range(6), sns.color_palette("Set2", n_cluster)))))

# %%
time_lag_c_s_mf_n = time_lag_c_s_mf_.loc[(cluster_labels==0)|(cluster_labels==1)]

# %%
sns.clustermap(time_lag_c_s_mf_n, cmap='coolwarm', col_cluster=False,
               vmax=.5, vmin=-.5
)

# %%
time_lag_c_s_mf_n['labels'] = labels.loc[time_lag_c_s_mf_n.index]

# %%
time_lag_c_s_mf_n['labels']
# Out:
# 1110015O18Rik     1
# 1110038B12Rik    10
# 2410006H16Rik     5
# 2610008E11Rik    10
# 2610316D01Rik     1
#                  ..
# Zmiz1os1          8
# Znrf3             1
# Zswim6            9
# Zswim9            1
# Zzz3              3
# Name: labels, Length: 1439, dtype: int64

# %%
clustercount = labels.reset_index().pivot_table(index='label', values='Gene', aggfunc='count')
clustercount_n = labels.loc[time_lag_c_s_mf_n.index].reset_index().pivot_table(index='label', values='index', aggfunc='count')

# %%
cluster_prop = pd.DataFrame((clustercount_n.values/clustercount.values).ravel(),
index=range(12))

# %%
cluster_prop
# Out:
#            0
# 0   0.504202
# 1   0.515575
# 2   0.513011
# 3   0.529661
# 4   0.448980
# 5   0.500000
# 6   0.492754
# 7   0.523364
# 8   0.531915
# 9   0.520000
# 10  0.462121
# 11  0.459016

# %%
fig, ax= plt.subplots(figsize=(4.8, 2.4))
sns.barplot(cluster_prop.reset_index(), x='index', y=0, palette='Paired')
ax.set_ylabel('%Negative dtw gene')
ax.set_xlabel('Cluster')
ax.set_yticklabels([0, 20, 40, 60, 80])
ax.grid(axis='y')
fig.savefig('../figures/fig7C_count.pdf')

# %%
mf.eval_dtw.plot_dtw(adata_out, 'Ccnd2',
                    False, 'velo_s_pseudotime',
                    figsave='../figures/fig7D_ccnd2.pdf'
                    )

# %%
mf.eval_dtw.plot_dtw(adata_out, 'Mki67',
                    False, 'velo_s_pseudotime',
                    figsave='../figures/fig7D_ccnd2.pdf'
                    )

# %%
mf.eval_dtw.plot_dtw(adata_out, 'Cdk12',
                    False, 'velo_s_pseudotime',
                    figsave='../figures/fig7D_cdk12.pdf'
                    )

# %%
mf.eval_dtw.plot_dtw(adata_out, 'Esf1',
                    False, 'velo_s_pseudotime',
                    #figsave='../figures/fig7D_cdk12.pdf'
                    )

# %%
mf.eval_dtw.plot_dtw(adata_out, 'Esf1',
                    False, 'velo_s_pseudotime',
                    figsave='../figures/fig7D_esf1.pdf'
                    )

# %%
subcellhl_1 = pd.read_excel('../temps/subcellhl_table1.xlsx',
                            sheet_name='3T3_rates_rep1')
subcellhl_2 = pd.read_excel('../temps/subcellhl_table1.xlsx',
                            sheet_name='3T3_rates_rep2')

# %%
subcellhl_1 = subcellhl_1.set_index('Symbol')
subcellhl_2 = subcellhl_2.set_index('Symbol')

# %%
target = ['half_life_chr.Mean', 'half_life_chr.MAP',
       'half_life_chr.0.025.quantile', 'half_life_chr.0.975.quantile',
       'half_life_nuc.Mean', 'half_life_nuc.MAP',
       'half_life_nuc.0.025.quantile', 'half_life_nuc.0.975.quantile',
       'half_life_nucexp_from_nucres.Mean', 'half_life_nucexp_from_nucres.MAP',
       'half_life_nucexp_from_nucres.0.025.quantile',
       'half_life_nucexp_from_nucres.0.975.quantile',
       'half_life_nucexp_from_dist.Mean', 'half_life_nucexp_from_dist.MAP',
       'half_life_nucexp_from_dist.0.025.quantile',
       'half_life_nucexp_from_dist.0.975.quantile', 'half_life_cyto.Mean',
       'half_life_cyto.MAP', 'half_life_cyto.0.025.quantile',
       'half_life_cyto.0.975.quantile', 'half_life_poly_entry.Mean',
       'half_life_poly_entry.MAP', 'half_life_poly_entry.0.025.quantile',
       'half_life_poly_entry.0.975.quantile', 'half_life_whole_cell.Mean',
       'half_life_whole_cell.MAP', 'half_life_whole_cell.0.025.quantile',
       'half_life_whole_cell.0.975.quantile', 'half_life_nucdeg.MAP',
       'half_life_nucdeg.0.025.quantile', 'half_life_nucdeg.0.975.quantile',
       'half_life_nucexp_from_nucdeg.MAP',
       'half_life_nucexp_from_nucdeg.0.025.quantile',
       'half_life_nucexp_from_nucdeg.0.975.quantile',
       'half_life_chr_release_from_nucdeg.MAP',
       'half_life_chr_release_from_nucdeg.0.025.quantile',
       'half_life_chr_release_from_nucdeg.0.975.quantile']

# %%
subcellhl_ = (subcellhl_2.loc[:, target].values + subcellhl_1.loc[:, target].values)/2
subcellhl_ = pd.DataFrame(subcellhl_, index=subcellhl_1.index, columns=target)
subcellhl_['PUND'] = subcellhl_1['PUND']
subcellhl_ = subcellhl_[subcellhl_.index.isin(adata_out.var_names)].dropna()
PUND = subcellhl_[subcellhl_['PUND']==1].index

# %%
subcellhl_['label'] = labels.loc[subcellhl_.index]['label']

# %%
subcell_pivot = subcellhl_.pivot_table(index='label', 
                       values=['half_life_nuc.MAP', 'half_life_cyto.MAP',
                               'half_life_nucexp_from_nucdeg.MAP',
                               'half_life_nucexp_from_dist.MAP',])

# %%
subcellhl_['label2'] = ['other' if l in [4, 5, 6, 7, 8,9,11] else l for l in subcellhl_['label']]

# %%
subcellhl_
# Out:
#                half_life_chr.Mean  half_life_chr.MAP  \
# Symbol
# Cdc45                        90.0               90.0
# Klf6                         12.0               12.0
# Axin2                        22.0               23.0
# Ccnd2                        74.0              109.5
# Mid2                         85.5               87.0
# ...                           ...                ...
# Rnaset2a                    385.0              390.0
# Syne1                       185.0              175.0
# Zfp994                       17.5               17.5
# Mpv17                       106.0              106.0
# A630089N07Rik                41.0               42.0
#
#                half_life_chr.0.025.quantile  half_life_chr.0.975.quantile  \
# Symbol
# Cdc45                                  82.0                          98.0
# Klf6                                   11.0                          12.5
# Axin2                                  15.0                          35.0
# Ccnd2                                  96.0                         112.0
# Mid2                                   71.0                         104.5
# ...                                     ...                           ...
# Rnaset2a                              305.0                         505.0
# Syne1                                 165.0                         200.0
# Zfp994                                 14.5                          21.5
# Mpv17                                  92.0                         120.0
# A630089N07Rik                          32.5                          51.5
#
#                half_life_nuc.Mean  half_life_nuc.MAP  \
# Symbol
# Cdc45                       115.0              115.0
# Klf6                         16.0               16.0
# Axin2                        59.5               67.0
# Ccnd2                       130.0              130.0
# Mid2                        111.0              112.0
# ...                           ...                ...
# Rnaset2a                    810.0              815.0
# Syne1                       145.0              150.0
# Zfp994                       25.5               26.0
# Mpv17                       140.0              140.0
# A630089N07Rik                46.5               48.0
#
#                half_life_nuc.0.025.quantile  half_life_nuc.0.975.quantile  \
# Symbol
# Cdc45                                 100.0                         130.0
# Klf6                                   14.5                          17.0
# Axin2                                  33.5                         132.0
# Ccnd2                                 125.0                         140.0
# Mid2                                   82.0                         150.0
# ...                                     ...                           ...
# Rnaset2a                              605.0                        1165.0
# Syne1                                 135.0                         160.0
# Zfp994                                 21.0                          32.0
# Mpv17                                 120.0                         165.0
# A630089N07Rik                          37.0                          59.5
#
#                half_life_nucexp_from_nucres.Mean  \
# Symbol
# Cdc45                                      43.00
# Klf6                                        7.35
# Axin2                                      41.00
# Ccnd2                                      44.00
# Mid2                                       46.00
# ...                                          ...
# Rnaset2a                                  418.00
# Syne1                                      15.50
# Zfp994                                     16.00
# Mpv17                                      57.50
# A630089N07Rik                              22.50
#
#                half_life_nucexp_from_nucres.MAP  ...  \
# Symbol                                           ...
# Cdc45                                     45.50  ...
# Klf6                                       7.95  ...
# Axin2                                     53.00  ...
# Ccnd2                                     47.00  ...
# Mid2                                      57.00  ...
# ...                                         ...  ...
# Rnaset2a                                 500.00  ...
# Syne1                                     17.50  ...
# Zfp994                                    17.50  ...
# Mpv17                                     62.50  ...
# A630089N07Rik                             25.00  ...
#
#                half_life_nucdeg.0.975.quantile  \
# Symbol
# Cdc45                                   6900.0
# Klf6                                    6350.0
# Axin2                                    465.5
# Ccnd2                                   6900.0
# Mid2                                    5300.0
# ...                                        ...
# Rnaset2a                                5850.0
# Syne1                                    220.0
# Zfp994                                  3300.0
# Mpv17                                   4400.0
# A630089N07Rik                             81.0
#
#                half_life_nucexp_from_nucdeg.MAP  \
# Symbol
# Cdc45                                     19.75
# Klf6                                       3.10
# Axin2                                   3465.50
# Ccnd2                                      5.95
# Mid2                                      15.25
# ...                                         ...
# Rnaset2a                                 377.50
# Syne1                                      4.95
# Zfp994                                    22.00
# Mpv17                                     31.75
# A630089N07Rik                             11.00
#
#                half_life_nucexp_from_nucdeg.0.025.quantile  \
# Symbol
# Cdc45                                                11.05
# Klf6                                                  1.95
# Axin2                                                 7.95
# Ccnd2                                                 3.75
# Mid2                                                  4.95
# ...                                                    ...
# Rnaset2a                                            216.70
# Syne1                                                 1.70
# Zfp994                                               14.00
# Mpv17                                                 6.70
# A630089N07Rik                                         3.10
#
#                half_life_nucexp_from_nucdeg.0.975.quantile  \
# Symbol
# Cdc45                                                25.00
# Klf6                                                  4.50
# Axin2                                               770.00
# Ccnd2                                                 8.45
# Mid2                                                 26.50
# ...                                                    ...
# Rnaset2a                                           1665.50
# Syne1                                                 7.45
# Zfp994                                               26.00
# Mpv17                                                40.50
# A630089N07Rik                                        28.50
#
#                half_life_chr_release_from_nucdeg.MAP  \
# Symbol
# Cdc45                                          100.0
# Klf6                                            12.0
# Axin2                                         5800.0
# Ccnd2                                          118.0
# Mid2                                            88.0
# ...                                              ...
# Rnaset2a                                      3570.0
# Syne1                                         6900.0
# Zfp994                                          18.0
# Mpv17                                          125.0
# A630089N07Rik                                 3115.0
#
#                half_life_chr_release_from_nucdeg.0.025.quantile  \
# Symbol
# Cdc45                                                      81.0
# Klf6                                                       10.0
# Axin2                                                    4800.0
# Ccnd2                                                     100.0
# Mid2                                                       67.5
# ...                                                         ...
# Rnaset2a                                                  315.0
# Syne1                                                     760.0
# Zfp994                                                     13.5
# Mpv17                                                      93.0
# A630089N07Rik                                            2460.0
#
#                half_life_chr_release_from_nucdeg.0.975.quantile  PUND  label  \
# Symbol
# Cdc45                                                     118.0   0.0      0
# Klf6                                                       15.0   0.0      9
# Axin2                                                    6900.0   0.0      1
# Ccnd2                                                     145.0   0.0      0
# Mid2                                                      375.0   0.0      8
# ...                                                         ...   ...    ...
# Rnaset2a                                                 3075.0   0.0      1
# Syne1                                                    6900.0   1.0      9
# Zfp994                                                     28.5   0.0      1
# Mpv17                                                     148.0   0.0      1
# A630089N07Rik                                            4600.0   0.0      0
#
#                label2
# Symbol
# Cdc45               0
# Klf6            other
# Axin2               1
# Ccnd2               0
# Mid2            other
# ...               ...
# Rnaset2a            1
# Syne1           other
# Zfp994              1
# Mpv17               1
# A630089N07Rik       0
#
# [1607 rows x 40 columns]

# %%
palette= ['grey']+sns.color_palette('Paired')[:4] + [sns.color_palette('Paired')[10]]

# %%
fig, axes = plt.subplots(1,4, figsize=(7.2, 2.4))
for i, y in enumerate(['half_life_nuc.MAP', 'half_life_cyto.MAP',
          'half_life_nucexp_from_nucdeg.MAP',
                               'half_life_nucexp_from_dist.MAP']):
    ax = axes[i]
    sns.boxplot(subcellhl_, x='label2', y=y, showfliers=False, 
            order=['other', 0, 1, 2, 3, 10],
            palette=palette,
            width=.5, whis=.5, ax=ax)
    ax.set_xlabel('')
    ax.set_ylabel('')
    ax.set_title(y.strip('.MAP').strip('half_life_'))
fig.tight_layout()
fig.savefig('../figures/fig7F_box.pdf')

# %%
import scipy

# %%
sns.heatmap(scipy.stats.zscore(subcell_pivot, axis=0).T,
            cmap='PiYG', center=0)
# Out:
# <Axes: xlabel='label'>

# %%
from scipy import stats

# %%
def ttestind_label(hl, label, alternative='greater'):
    target = subcellhl_[hl]
    target = target - np.min(target)
    target = target/np.max(target)
    
    a = target[subcellhl_['label'].isin(label)]
    b =  target[~subcellhl_['label'].isin(label)]
    print('target show greater', stats.ks_2samp(a, b,
                alternative='greater'))
    print('target show less', stats.ks_2samp(a, b,
                alternative='less'))
    print( 
    )
ttestind_label('half_life_chr.MAP', [0, 1, 2,3])
ttestind_label('half_life_nuc.MAP', [0, 1, 2,3])
ttestind_label('half_life_cyto.MAP', [0, 1, 2,3])
ttestind_label('half_life_nucexp_from_nucdeg.MAP', [0, 1, 2,3])
ttestind_label('half_life_nucexp_from_dist.MAP', [0, 1, 2,3])
# Out:
# target show greater KstestResult(statistic=0.012882701615095981, pvalue=0.8823267585996113, statistic_location=0.004490014743331993, statistic_sign=1)
# target show less KstestResult(statistic=0.0686769264234053, pvalue=0.036948493512104774, statistic_location=0.15560916767189384, statistic_sign=-1)
#
# target show greater KstestResult(statistic=0.008467018326173257, pvalue=0.9449607573032569, statistic_location=0.011351543100390209, statistic_sign=1)
# target show less KstestResult(statistic=0.08192035093443543, pvalue=0.009287102421711404, statistic_location=0.19829726853494148, statistic_sign=-1)
#
# target show greater KstestResult(statistic=0.08656261895698515, pvalue=0.005406316023369889, statistic_location=0.06512605042016807, statistic_sign=1)
# target show less KstestResult(statistic=0.01756666122863306, pvalue=0.7967580435426698, statistic_location=0.2273576097105509, statistic_sign=-1)
#
# target show greater KstestResult(statistic=0.00870810448275237, pvalue=0.9420798543398672, statistic_location=0.00033338648190291213, statistic_sign=1)
# target show less KstestResult(statistic=0.04978157231678358, pvalue=0.17465427102682377, statistic_location=0.0024424183565495946, statistic_sign=-1)
#
# target show greater KstestResult(statistic=0.0, pvalue=1.0, statistic_location=1.0, statistic_sign=1)
# target show less KstestResult(statistic=0.08350463139195534, pvalue=0.007746988658395122, statistic_location=0.026249958007029443, statistic_sign=-1)

# %%
ttestind_label('half_life_chr.MAP', [10])
ttestind_label('half_life_nuc.MAP', [10])
ttestind_label('half_life_cyto.MAP', [10])
ttestind_label('half_life_nucexp_from_nucdeg.MAP', [10])
ttestind_label('half_life_nucexp_from_dist.MAP', [10])
# Out:
# target show greater KstestResult(statistic=0.2277369063273744, pvalue=1.4294824457911427e-05, statistic_location=0.058102131081624445, statistic_sign=1)
# target show less KstestResult(statistic=0.006545355463150537, pvalue=0.9868285153083597, statistic_location=0.004490014743331993, statistic_sign=-1)
#
# target show greater KstestResult(statistic=0.2391216784542299, pvalue=4.532812592098857e-06, statistic_location=0.05427456544874069, statistic_sign=1)
# target show less KstestResult(statistic=0.010040160642570281, pvalue=0.9718673273729379, statistic_location=0.0046115643845335225, statistic_sign=-1)
#
# target show greater KstestResult(statistic=0.009370816599732263, pvalue=0.9748480408947671, statistic_location=0.41643323996265175, statistic_sign=1)
# target show less KstestResult(statistic=0.22535570008648162, pvalue=1.804209313329285e-05, statistic_location=0.046451914098972924, statistic_sign=-1)
#
# target show greater KstestResult(statistic=0.12006136640959117, pvalue=0.04431247259497875, statistic_location=0.0016379422806534376, statistic_sign=1)
# target show less KstestResult(statistic=0.04998163746431152, pvalue=0.5714282577401573, statistic_location=0.0005942976416530171, statistic_sign=-1)
#
# target show greater KstestResult(statistic=0.22758882136214476, pvalue=1.450529098887513e-05, statistic_location=0.02499991482812133, statistic_sign=1)
# target show less KstestResult(statistic=0.03600241674663255, pvalue=0.7425488915909146, statistic_location=0.0018124569531622061, statistic_sign=-1)

# %%
def ttestind_label(hl, label, alternative='greater'):
    target = subcellhl_[hl]
    target = target - np.min(target)
    target = target/np.max(target)
    
    a = target[subcellhl_['label'].isin(label)]
    b =  target[~subcellhl_['label'].isin(label)]
    
    great = stats.ks_2samp(b, a,
                alternative='greater')
    print(great)
    less = stats.ks_2samp(b, a,
                alternative='less')
    print(less)
    return great[1], less[1]

pvalues_g = []
pvalues_l = []
for i in range(12):
    pvalue_g = []
    pvalue_l = []
    for hl in ['half_life_nuc.MAP',
               'half_life_cyto.MAP',
               'half_life_nucexp_from_nucdeg.MAP',
               'half_life_nucexp_from_dist.MAP',
               ]:
        g, l = ttestind_label(hl, [i])
        pvalue_g.append(g)
        pvalue_l.append(l)
    pvalues_g.append(pvalue_g)
    pvalues_l.append(pvalue_l)
# Out:
# KstestResult(statistic=0.01496792587312901, pvalue=0.9132544264243416, statistic_location=0.005321035828307911, statistic_sign=1)
# KstestResult(statistic=0.17387111651503082, pvalue=1.7559075717911815e-05, statistic_location=0.09187655196878326, statistic_sign=-1)
# KstestResult(statistic=0.17256439282769415, pvalue=2.069429103590376e-05, statistic_location=0.0546218487394958, statistic_sign=1)
# KstestResult(statistic=0.005076656464438947, pvalue=0.9865780799358513, statistic_location=0.4047619047619048, statistic_sign=-1)
# KstestResult(statistic=0.0490510530655598, pvalue=0.4094281765193446, statistic_location=0.0007030106248822276, statistic_sign=1)
# KstestResult(statistic=0.07893449610778025, pvalue=0.10246967182293003, statistic_location=0.001224832944382438, statistic_sign=-1)
# KstestResult(statistic=0.02377258815144019, pvalue=0.8032818913433432, statistic_location=0.008062414097691609, statistic_sign=1)
# KstestResult(statistic=0.12460344080611574, pvalue=0.003576163536103326, statistic_location=0.04562495884257635, statistic_sign=-1)
# KstestResult(statistic=0.1592109144787216, pvalue=4.67701616071071e-09, statistic_location=0.09897126640652713, statistic_sign=1)
# KstestResult(statistic=0.0031572038940505353, pvalue=0.9896802287697646, statistic_location=0.005321035828307911, statistic_sign=-1)
# KstestResult(statistic=0.007431444756389816, pvalue=0.9528767541641077, statistic_location=0.41643323996265175, statistic_sign=1)
# KstestResult(statistic=0.1576480571180446, pvalue=6.793461012286051e-09, statistic_location=0.048786181139122316, statistic_sign=-1)
# KstestResult(statistic=0.09611987099383143, pvalue=0.0008885656649231218, statistic_location=0.0012900607343199642, statistic_sign=1)
# KstestResult(statistic=0.0051426790988130236, pvalue=0.9757347196574085, statistic_location=0.0661554740610822, statistic_sign=-1)
# KstestResult(statistic=0.14323430264741077, pvalue=1.7872792787201937e-07, statistic_location=0.04562491571757449, statistic_sign=1)
# KstestResult(statistic=0.0, pvalue=1.0, statistic_location=1.0, statistic_sign=-1)
# KstestResult(statistic=0.15934538329267806, pvalue=0.0015671122043942262, statistic_location=0.06172401560837176, statistic_sign=1)
# KstestResult(statistic=0.027927180389490942, pvalue=0.807274617677127, statistic_location=0.004966300106420717, statistic_sign=-1)
# KstestResult(statistic=0.008587595473267486, pvalue=0.9755016608535424, statistic_location=0.4397759103641457, statistic_sign=1)
# KstestResult(statistic=0.18602291358419643, pvalue=0.00015126932136111577, statistic_location=0.06045751633986928, statistic_sign=-1)
# KstestResult(statistic=0.05453473027552285, pvalue=0.45888594264005744, statistic_location=0.004768876197654699, statistic_sign=1)
# KstestResult(statistic=0.03371056104290798, pvalue=0.7356681286054767, statistic_location=0.000695763092666947, statistic_sign=-1)
# KstestResult(statistic=0.09366877274363178, pvalue=0.10518326007619755, statistic_location=0.02562495798007632, statistic_sign=1)
# KstestResult(statistic=0.06564661894669492, pvalue=0.3265073557103987, statistic_location=0.003999957047498149, statistic_sign=-1)
# KstestResult(statistic=0.0013734705453366826, pvalue=0.998289371896371, statistic_location=0.006385242993969493, statistic_sign=1)
# KstestResult(statistic=0.23778462037112066, pvalue=2.01259260624398e-08, statistic_location=0.05108194395175594, statistic_sign=-1)
# KstestResult(statistic=0.17646463009480592, pvalue=5.8718077673757416e-05, statistic_location=0.03583099906629319, statistic_sign=1)
# KstestResult(statistic=0.006251519325824488, pvalue=0.9833776185165201, statistic_location=0.27637721755368816, statistic_sign=-1)
# KstestResult(statistic=0.006733652054128515, pvalue=0.9810376479306309, statistic_location=0.0036020235109945065, statistic_sign=1)
# KstestResult(statistic=0.08642330443237987, pvalue=0.09463141232561131, statistic_location=0.0015727144907159113, statistic_sign=-1)
# KstestResult(statistic=0.00945628393161008, pvalue=0.9663781610464577, statistic_location=0.0, statistic_sign=1)
# KstestResult(statistic=0.1917713313345758, pvalue=1.0064656858523222e-05, statistic_location=0.017999914526246316, statistic_sign=-1)
# KstestResult(statistic=0.13415982312065697, pvalue=0.39175997668723445, statistic_location=0.049663001064207166, statistic_sign=1)
# KstestResult(statistic=0.11054958938723942, pvalue=0.522990446110594, statistic_location=0.19829726853494148, statistic_sign=-1)
# KstestResult(statistic=0.10741735102126763, pvalue=0.5411628936126921, statistic_location=0.02777777777777778, statistic_sign=1)
# KstestResult(statistic=0.12963255422194145, pvalue=0.4158351445087993, statistic_location=0.0861344537815126, statistic_sign=-1)
# KstestResult(statistic=0.09007159401979364, pvalue=0.6431983459694427, statistic_location=0.0022902201800287, statistic_sign=1)
# KstestResult(statistic=0.11118130132659507, pvalue=0.5193232802237874, statistic_location=0.00592848135209961, statistic_sign=-1)
# KstestResult(statistic=0.13744998947146767, pvalue=0.37464543930266553, statistic_location=0.03499995838437321, statistic_sign=1)
# KstestResult(statistic=0.16045483259633608, pvalue=0.2670144272052332, statistic_location=0.06249995957031076, statistic_sign=-1)
# KstestResult(statistic=0.09653638108532542, pvalue=0.42260579752567023, statistic_location=0.08691025186236254, statistic_sign=1)
# KstestResult(statistic=0.09687081951957192, pvalue=0.4201392364529025, statistic_location=0.03086200780418588, statistic_sign=-1)
# KstestResult(statistic=0.021753039027511197, pvalue=0.946165651013738, statistic_location=0.009920634920634922, statistic_sign=1)
# KstestResult(statistic=0.20706101320304776, pvalue=0.02176430144905224, statistic_location=0.0546218487394958, statistic_sign=-1)
# KstestResult(statistic=0.027816553248415053, pvalue=0.9183199476840517, statistic_location=0.00040586180405571907, statistic_sign=1)
# KstestResult(statistic=0.22043855057290757, pvalue=0.013121551728452535, statistic_location=0.0010653872356462624, statistic_sign=-1)
# KstestResult(statistic=0.08683766649217704, pvalue=0.4953919066366578, statistic_location=0.009124914143511924, statistic_sign=1)
# KstestResult(statistic=0.05118362124120281, pvalue=0.7725068218575382, statistic_location=0.1674999209734341, statistic_sign=-1)
# KstestResult(statistic=0.2121260343730108, pvalue=0.036000558233116646, statistic_location=0.04398722951401206, statistic_sign=1)
# KstestResult(statistic=0.038475139684560435, pvalue=0.8783494577480857, statistic_location=0.15572898190847817, statistic_sign=-1)
# KstestResult(statistic=0.14481222151495862, pvalue=0.20757565699439876, statistic_location=0.08333333333333333, statistic_sign=1)
# KstestResult(statistic=0.07645519485112101, pvalue=0.6302855295068985, statistic_location=0.02777777777777778, statistic_sign=-1)
# KstestResult(statistic=0.038369050144989036, pvalue=0.8791082278873709, statistic_location=0.03970198147530766, statistic_sign=1)
# KstestResult(statistic=0.17508310347266426, pvalue=0.10248163490397452, statistic_location=0.0012900607343199642, statistic_sign=-1)
# KstestResult(statistic=0.05281490911662777, pvalue=0.7933938539823665, statistic_location=0.009124914143511924, statistic_sign=1)
# KstestResult(statistic=0.05714689864912653, pvalue=0.7652076436864198, statistic_location=0.01499995752187317, statistic_sign=-1)
# KstestResult(statistic=0.1560315293986575, pvalue=0.10193465133402739, statistic_location=0.07697765164952111, statistic_sign=1)
# KstestResult(statistic=0.07563434810461521, pvalue=0.570798509391584, statistic_location=0.21603405462930117, statistic_sign=-1)
# KstestResult(statistic=0.15679748210455952, pvalue=0.09969747886702474, statistic_location=0.10014005602240897, statistic_sign=1)
# KstestResult(statistic=0.0601899562710637, pvalue=0.6953155273214457, statistic_location=0.041783380018674134, statistic_sign=-1)
# KstestResult(statistic=0.23569061081246692, pvalue=0.005721559215488427, statistic_location=0.0015727144907159113, statistic_sign=1)
# KstestResult(statistic=0.038269782469431524, pvalue=0.8552808029019099, statistic_location=0.00040586180405571907, statistic_sign=-1)
# KstestResult(statistic=0.17206083057126145, pvalue=0.06278950666103578, statistic_location=0.009374914154293174, statistic_sign=1)
# KstestResult(statistic=0.027630003063810825, pvalue=0.9164274774855902, statistic_location=0.13124996253515464, statistic_sign=-1)
# KstestResult(statistic=0.044683153725706914, pvalue=0.7820220717819539, statistic_location=0.011706278822277403, statistic_sign=1)
# KstestResult(statistic=0.0845997973657548, pvalue=0.4360895058087851, statistic_location=0.15218162468960625, statistic_sign=-1)
# KstestResult(statistic=0.03288201160541586, pvalue=0.8702065096034703, statistic_location=0.012021475256769375, statistic_sign=1)
# KstestResult(statistic=0.13395735470203554, pvalue=0.13110809675431445, statistic_location=0.06629318394024276, statistic_sign=-1)
# KstestResult(statistic=0.0422998986828774, pvalue=0.8010759201269301, statistic_location=0.0004928321906390874, statistic_sign=1)
# KstestResult(statistic=0.12414801510546192, pvalue=0.17368447344281304, statistic_location=0.00186986331154242, statistic_sign=-1)
# KstestResult(statistic=0.013850511190936722, pvalue=0.9707858059435295, statistic_location=0.12249991903280903, statistic_sign=1)
# KstestResult(statistic=0.11053928341162383, pvalue=0.2477928250261064, statistic_location=0.003187457012459084, statistic_sign=-1)
# KstestResult(statistic=0.014790957591441403, pvalue=0.9337607681138251, statistic_location=0.03831145796381696, statistic_sign=1)
# KstestResult(statistic=0.06493957038245525, pvalue=0.31103695200604825, statistic_location=0.13444483859524653, statistic_sign=-1)
# KstestResult(statistic=0.13250916523679596, pvalue=0.008507572445158198, statistic_location=0.06512605042016807, statistic_sign=1)
# KstestResult(statistic=0.013689253935660506, pvalue=0.9420939154048334, statistic_location=0.38141923436041086, statistic_sign=-1)
# KstestResult(statistic=0.03938473366900134, pvalue=0.6441258333546026, statistic_location=0.001435011378625578, statistic_sign=1)
# KstestResult(statistic=0.041710031597798465, pvalue=0.6114752945655021, statistic_location=0.006870660540086101, statistic_sign=-1)
# KstestResult(statistic=0.0, pvalue=1.0, statistic_location=1.0, statistic_sign=1)
# KstestResult(statistic=0.10530411709000216, pvalue=0.04836846934656805, statistic_location=0.04062495862695134, statistic_sign=-1)
# KstestResult(statistic=0.010040160642570281, pvalue=0.9718673273729379, statistic_location=0.0046115643845335225, statistic_sign=1)
# KstestResult(statistic=0.2391216784542299, pvalue=4.532812592098857e-06, statistic_location=0.05427456544874069, statistic_sign=-1)
# KstestResult(statistic=0.22535570008648162, pvalue=1.804209313329285e-05, statistic_location=0.046451914098972924, statistic_sign=1)
# KstestResult(statistic=0.009370816599732263, pvalue=0.9748480408947671, statistic_location=0.41643323996265175, statistic_sign=-1)
# KstestResult(statistic=0.04998163746431152, pvalue=0.5714282577401573, statistic_location=0.0005942976416530171, statistic_sign=1)
# KstestResult(statistic=0.12006136640959117, pvalue=0.04431247259497875, statistic_location=0.0016379422806534376, statistic_sign=-1)
# KstestResult(statistic=0.03600241674663255, pvalue=0.7425488915909146, statistic_location=0.0018124569531622061, statistic_sign=1)
# KstestResult(statistic=0.22758882136214476, pvalue=1.450529098887513e-05, statistic_location=0.02499991482812133, statistic_sign=-1)
# KstestResult(statistic=0.21553571428571427, pvalue=0.04640381318491807, statistic_location=0.04114934373891451, statistic_sign=1)
# KstestResult(statistic=0.06384920634920635, pvalue=0.7426808829262797, statistic_location=0.18056048244058176, statistic_sign=-1)
# KstestResult(statistic=0.06396825396825397, pvalue=0.7418515286679938, statistic_location=0.11647992530345472, statistic_sign=1)
# KstestResult(statistic=0.13525793650793652, pvalue=0.29054039771230944, statistic_location=0.07329598506069095, statistic_sign=-1)
# KstestResult(statistic=0.1238888888888889, pvalue=0.35229675062937477, statistic_location=0.0008697038658336837, statistic_sign=1)
# KstestResult(statistic=0.11210317460317461, pvalue=0.4227350840649988, statistic_location=0.003899172331821015, statistic_sign=-1)
# KstestResult(statistic=0.15676587301587303, pvalue=0.19291596766619226, statistic_location=0.007787414085832234, statistic_sign=1)
# KstestResult(statistic=0.07972222222222222, pvalue=0.6374362095464511, statistic_location=0.07249991687655892, statistic_sign=-1)

# %%
colname = ['half_life_nuc.MAP',
               'half_life_cyto.MAP',
               'half_life_nucexp_from_nucdeg.MAP',
               'half_life_nucexp_from_dist.MAP',
               ]

# %%
pvalues_g_ = pd.DataFrame(pvalues_g, columns=[c+'_greater' for c in colname])
pvalues_l_ = pd.DataFrame(pvalues_l, columns=[c+'_less' for c in colname])

# %%
pd.concat([pvalues_g_, pvalues_l_], axis=1)
# Out:
#     half_life_nuc.MAP_greater  half_life_cyto.MAP_greater  \
# 0                9.132544e-01                    0.000021
# 1                4.677016e-09                    0.952877
# 2                1.567112e-03                    0.975502
# 3                9.982894e-01                    0.000059
# 4                3.917600e-01                    0.541163
# 5                4.226058e-01                    0.946166
# 6                3.600056e-02                    0.207576
# 7                1.019347e-01                    0.099697
# 8                7.820221e-01                    0.870207
# 9                9.337608e-01                    0.008508
# 10               9.718673e-01                    0.000018
# 11               4.640381e-02                    0.741852
#
#     half_life_nucexp_from_nucdeg.MAP_greater  \
# 0                                   0.409428
# 1                                   0.000889
# 2                                   0.458886
# 3                                   0.981038
# 4                                   0.643198
# 5                                   0.918320
# 6                                   0.879108
# 7                                   0.005722
# 8                                   0.801076
# 9                                   0.644126
# 10                                  0.571428
# 11                                  0.352297
#
#     half_life_nucexp_from_dist.MAP_greater  half_life_nuc.MAP_less  \
# 0                             8.032819e-01            1.755908e-05
# 1                             1.787279e-07            9.896802e-01
# 2                             1.051833e-01            8.072746e-01
# 3                             9.663782e-01            2.012593e-08
# 4                             3.746454e-01            5.229904e-01
# 5                             4.953919e-01            4.201392e-01
# 6                             7.933939e-01            8.783495e-01
# 7                             6.278951e-02            5.707985e-01
# 8                             9.707858e-01            4.360895e-01
# 9                             1.000000e+00            3.110370e-01
# 10                            7.425489e-01            4.532813e-06
# 11                            1.929160e-01            7.426809e-01
#
#     half_life_cyto.MAP_less  half_life_nucexp_from_nucdeg.MAP_less  \
# 0              9.865781e-01                               0.102470
# 1              6.793461e-09                               0.975735
# 2              1.512693e-04                               0.735668
# 3              9.833776e-01                               0.094631
# 4              4.158351e-01                               0.519323
# 5              2.176430e-02                               0.013122
# 6              6.302855e-01                               0.102482
# 7              6.953155e-01                               0.855281
# 8              1.311081e-01                               0.173684
# 9              9.420939e-01                               0.611475
# 10             9.748480e-01                               0.044312
# 11             2.905404e-01                               0.422735
#
#     half_life_nucexp_from_dist.MAP_less
# 0                              0.003576
# 1                              1.000000
# 2                              0.326507
# 3                              0.000010
# 4                              0.267014
# 5                              0.772507
# 6                              0.765208
# 7                              0.916427
# 8                              0.247793
# 9                              0.048368
# 10                             0.000015
# 11                             0.637436

# %%
df = pd.concat([pvalues_g_, pvalues_l_], axis=1).T.sort_index().T

# %%
text
# Out:
# 2.069429103590376e-05

# %%
fig, ax = plt.subplots()
im = ax.imshow(-np.log2(df.T), vmax=10, cmap='vlag')
ax.set_xticks(range(12), labels=range(12),
              )
ax.set_yticks(range(8), ['Cytoplasmic half-life ↑', 'Cytoplasmic half-life ↓', 'Nuclear half-life ↑', 'Nuclear half-life ↓',
                         'Nuclear export half-life ↑', 'Nuclear export half-life ↓',
                         'Nuclear degradataion half-life ↑', 'Nuclear degradation half-life ↓']
              
)
plt.title('One-sided KS test of RNA half life between gene clusters vs. background)')
for i in range(8):
    for j in range(12):
        text = df.T.iloc[i, j]
        if text<=0.001:
            ax.text(j, i, '***',
                       ha="center", va="center", color="w")
        elif text<=0.005:
            ax.text(j, i, '**',
                       ha="center", va="center", color="w")
        elif text<=0.05:
            ax.text(j, i, '*',
                       ha="center", va="center", color="black")
plt.colorbar(im, label='-log10(p-value)')
fig.savefig('../figures/fig7E_heat.pdf')

# %%
hek_speckle = pd.read_excel('../temps/slam-rt_tag_table1.xlsx',
                   sheet_name='HEK293T_SC35',
                   header=0)
k562_speckle = pd.read_excel('../temps/slam-rt_tag_table1.xlsx',
                   sheet_name='K562_SC35',
                   header=0)

# %%
hek_polycomb = pd.read_excel('../temps/slam-rt_tag_table1.xlsx',
                   sheet_name='HEK293T_H3K27me3',
                   header=1)
k562_polycomb = pd.read_excel('../temps/slam-rt_tag_table1.xlsx',
                   sheet_name='K562_H3K27me3',
                   header=0)

# %%
hek_speckle
# Out:
#       chromosome     start       end   width strand   source  \
# 0           chr1     14363     29806   15444      -   HAVANA
# 1           chr1    134901    139379    4479      -  ENSEMBL
# 2           chr1    227615    267253   39639      -   HAVANA
# 3           chr1    317720    453948  136229      +   HAVANA
# 4           chr1    564442    564813     372      +   HAVANA
# ...          ...       ...       ...     ...    ...      ...
# 25262       chrY   5075256   5076110     855      -   HAVANA
# 25263       chrY   5205786   5207005    1220      -   HAVANA
# 25264       chrY  15398518  15399258     741      +   HAVANA
# 25265       chrY  21034387  21239302  204916      -   HAVANA
# 25266       chrY  21154353  21154595     243      -   HAVANA
#
#                  gene_id       gene_type      gene_name     IgG n1    SC35 n1  \
# 0      ENSG00000227232.4      pseudogene         WASH7P   0.000000   1.839336
# 1      ENSG00000237683.5  protein_coding     AL627309.1   0.000000   0.000000
# 2      ENSG00000228463.4         lincRNA     AP006222.2   0.000000   5.518009
# 3      ENSG00000237094.7         lincRNA  RP4-669L17.10   0.000000   0.000000
# 4      ENSG00000225972.1      pseudogene       MTND1P23   1.671518   0.000000
# ...                  ...             ...            ...        ...        ...
# 25262  ENSG00000231341.1      pseudogene        VDAC1P6   0.000000   0.000000
# 25263  ENSG00000235001.2      pseudogene       EIF4A1P2   4.178795   0.000000
# 25264  ENSG00000215414.3      pseudogene        PSMA6P1  10.864866  11.036017
# 25265  ENSG00000176728.3         lincRNA         TTTY14   0.000000   0.000000
# 25266  ENSG00000185275.6      pseudogene         CD24P4   1.671518   0.000000
#
#           IgG n2    SC35 n2     IgG n3    SC35 n3  Results_log2  \
# 0       0.000000   6.491934   0.000000   7.873737      5.033245
# 1       0.000000   1.081989   0.000000   0.000000      1.457859
# 2       0.000000   0.000000   0.000000   0.000000      1.873722
# 3       0.000000   1.081989   0.000000   0.000000      1.457859
# 4       0.000000   0.000000   3.628431   8.748597     -0.240172
# ...          ...        ...        ...        ...           ...
# 25262   0.000000   0.000000   2.177059   0.000000     -0.780356
# 25263   0.000000   1.081989   4.354117   1.749719     -1.030986
# 25264  17.764310  12.983868  34.832937  20.121774     -0.430352
# 25265   0.000000   0.000000   0.725686   0.000000     -0.320858
# 25266   4.229598   3.245967   0.000000   3.499439      0.203423
#
#        Results_pvalue diffexpressed
# 0            0.169702            NO
# 1                 NaN            NO
# 2                 NaN            NO
# 3                 NaN            NO
# 4                 NaN            NO
# ...               ...           ...
# 25262             NaN            NO
# 25263             NaN            NO
# 25264        0.787930            NO
# 25265             NaN            NO
# 25266             NaN            NO
#
# [25267 rows x 18 columns]

# %%
df_upcase = labels.copy()
df_upcase.index = np.char.upper(df_upcase.index.values.astype('str'))

# %%
hek_speckle = hek_speckle[hek_speckle['gene_name'].isin(df_upcase.index)]
k562_speckle = k562_speckle[k562_speckle['gene_name'].isin(df_upcase.index)]
hek_polycomb = hek_polycomb[hek_polycomb['gene_name'].isin(df_upcase.index)]
k562_polycomb = k562_polycomb[k562_polycomb['gene_name'].isin(df_upcase.index)]

# %%
hek_speckle_gene = hek_speckle[hek_speckle['diffexpressed']=='UP']['gene_name']
k562_speckle_gene = k562_speckle[k562_speckle['diffexpressed']=='UP']['gene_name']
speckle_gene = list(set(hek_speckle_gene)|set(k562_speckle_gene))
speckle_total_gene = list(set(hek_speckle['gene_name'])|set(k562_speckle))

# %%
hek_polycomb_gene = hek_polycomb[hek_polycomb['diffexpressed']=='UP']['gene_name']
k562_polycomb_gene = k562_polycomb[k562_polycomb['diffexpressed']=='UP']['gene_name']
polycomb_gene = list(set(hek_polycomb_gene)|set(k562_polycomb_gene))
polycomb_total_gene = list(set(hek_polycomb['gene_name'])|set(k562_polycomb))

# %%
from scipy.stats import fisher_exact

# %%
fishers = []
for name, geneset in zip(
    ['polycomb', 'speckle'],
    [[polycomb_gene, polycomb_total_gene], [speckle_gene, speckle_total_gene]]):
    
    total_target, total_gene = geneset
    total_nontarget = set(total_gene) - set(total_target)
    
    A = len(total_target)
    B = len(total_nontarget)
    
    fisher_ = []
    for i in range(12):
        temp = df_upcase[df_upcase['label']==i]
        
        a = len(set(total_target)&set(temp.index))
        b = len(set(total_nontarget)&set(temp.index))

        table = [[a, b],
                [A - a, B - b]]
        
        oddsratio, p_value = fisher_exact(table, alternative='greater')  # or 'two-sided'

        fisher_.append([oddsratio, p_value])
        
    fisher_ = pd.DataFrame(fisher_, index=range(12), columns=['oddsR', 'pval'])
    fisher_['data'] = name
    fishers.append(fisher_)

# %%
fishers =pd.concat(fishers)
fishers = fishers.reset_index()
pval = fishers.pivot_table(index='index', columns='data', values='pval')

# %%
sns.heatmap(-np.log10(pval), vmax=3,  cmap='coolwarm',
            cbar_kws={'label': '-np.log10(p-val)',}, linewidth=.5, linecolor='black')
plt.savefig('../figures/fig7G_heat.pdf')
# Out:
# <AxesSubplot:xlabel='data', ylabel='index'>

# %%
labels_speckle = labels.loc[df_upcase.index.isin(speckle_gene)]
labels_polycomb = labels.loc[df_upcase.index.isin(polycomb_gene)]

# %%
time_lag_c_s_mf_n
# Out:
#                  0         1         2         3         4         5  \
# 1110015O18Rik  0.0 -0.029478 -0.047619 -0.047619 -0.117914 -0.195011
# 1500004A13Rik  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2410006H16Rik  0.0  0.047619  0.047619 -0.006803 -0.072562 -0.138322
# 2610037D02Rik  0.0  0.000000 -0.045351 -0.068027 -0.138322 -0.208617
# 2610316D01Rik  0.0 -0.015873 -0.079365 -0.142857 -0.206349 -0.269841
# ...            ...       ...       ...       ...       ...       ...
# Zic5           0.0  0.000000  0.000000 -0.006803 -0.047619 -0.090703
# Znrf3          0.0 -0.024943 -0.095238 -0.095238 -0.099773 -0.172336
# Zranb2         0.0  0.000000 -0.040816 -0.108844 -0.176871 -0.244898
# Zscan26        0.0  0.000000  0.000000  0.000000  0.000000 -0.031746
# Zzz3           0.0 -0.065760 -0.131519 -0.197279 -0.263039 -0.328798
#
#                       6         7         8         9  ...        13  \
# 1110015O18Rik -0.272109 -0.349206 -0.426304 -0.476190  ... -0.569161
# 1500004A13Rik -0.061224 -0.126984 -0.192744 -0.258503  ... -0.380952
# 2410006H16Rik -0.142857 -0.174603 -0.240363 -0.285714  ... -0.285714
# 2610037D02Rik -0.278912 -0.349206 -0.380952 -0.367347  ... -0.133787
# 2610316D01Rik -0.285714 -0.285714 -0.285714 -0.285714  ... -0.126984
# ...                 ...       ...       ...       ...  ...       ...
# Zic5          -0.108844 -0.174603 -0.240363 -0.285714  ... -0.240363
# Znrf3         -0.238095 -0.269841 -0.342404 -0.414966  ... -0.523810
# Zranb2        -0.312925 -0.333333 -0.333333 -0.292517  ... -0.020408
# Zscan26       -0.095238 -0.142857 -0.174603 -0.190476  ... -0.301587
# Zzz3          -0.380952 -0.380952 -0.380952 -0.380952  ... -0.380952
#
#                      14        15        16        17        18        19  \
# 1110015O18Rik -0.492063 -0.414966 -0.337868 -0.260771 -0.183673 -0.106576
# 1500004A13Rik -0.380952 -0.346939 -0.281179 -0.215420 -0.149660 -0.083900
# 2410006H16Rik -0.285714 -0.285714 -0.281179 -0.238095 -0.197279 -0.131519
# 2610037D02Rik -0.063492  0.000000  0.000000  0.004535  0.074830  0.092971
# 2610316D01Rik -0.063492 -0.047619 -0.031746  0.031746  0.047619  0.031746
# ...                 ...       ...       ...       ...       ...       ...
# Zic5          -0.222222 -0.156463 -0.090703 -0.024943  0.040816  0.095238
# Znrf3         -0.460317 -0.387755 -0.315193 -0.242630 -0.170068 -0.097506
# Zranb2         0.047619  0.095238  0.095238  0.095238  0.095238  0.095238
# Zscan26       -0.333333 -0.333333 -0.317460 -0.253968 -0.190476 -0.126984
# Zzz3          -0.317460 -0.285714 -0.285714 -0.263039 -0.197279 -0.131519
#
#                      20   21  labels
# 1110015O18Rik -0.029478  0.0       1
# 1500004A13Rik -0.018141  0.0       8
# 2410006H16Rik -0.065760  0.0       5
# 2610037D02Rik  0.047619  0.0       9
# 2610316D01Rik  0.000000  0.0       1
# ...                 ...  ...     ...
# Zic5           0.065760  0.0       1
# Znrf3         -0.024943  0.0       1
# Zranb2         0.068027  0.0      10
# Zscan26       -0.063492  0.0       3
# Zzz3          -0.065760  0.0       3
#
# [1301 rows x 23 columns]
